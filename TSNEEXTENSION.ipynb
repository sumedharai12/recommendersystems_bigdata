# %%
#importing Libraries
import pandas as pd
import json

# %%
#reading the good reads fuzzy log metadata
w=pd.read_json("goodreads_book_genres_initial.json",lines=True)

# %%
#creating a dictionary of genres
dict_genres=list(w['genres'])

# %%
#making a dataframe from dictionary of genres
df=pd.DataFrame.from_dict(dict_genres,orient="columns")

# %%
#checking if the book id is common 
df['book_id']=w['book_id']

# %%
df.ix[43615,:]
# Out:
# C:\Users\Hitesh Arsenal Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# children                                      NaN
# comics, graphic                               NaN
# fantasy, paranormal                       10730.0
# fiction                                    4317.0
# history, historical fiction, biography        NaN
# mystery, thriller, crime                    385.0
# non-fiction                                   NaN
# poetry                                        NaN
# romance                                       NaN
# young-adult                                   NaN
# book_id                                   43615.0
# Name: 43615, dtype: float64

# %%
#loading the items factors and bookmetadata
test=pd.read_csv("ItemFactors.csv")
map_1=pd.read_csv("book_id_map.csv")

# %%
#checking test dataframe
test.head()
# Out:
#    Unnamed: 0   id                                           features
# 0           0   43  [0.05561315268278122, -1.3075635433197021, -0....
# 1           1   63  [0.9563032984733582, 0.07040280103683472, -1.7...
# 2           2  103  [0.6581641435623169, 0.8863093852996826, -0.29...
# 3           3  143  [-0.500838577747345, 1.2483102083206177, -0.21...
# 4           4  183  [0.48275044560432434, 0.09569288045167923, 0.5...

# %%
#mapping the indexes
map_1.index=map_1.book_id_csv
map_1.drop(['book_id_csv'],axis=1,inplace=True)

# %%
#converting the index
index_id=test['id']
map_1=map_1.ix[index_id,:]
# Out:
# C:\Users\Hitesh Arsenal Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
map_1.index=range(len(map_1['book_id']))

# %%
map_1.head()
# Out:
#     book_id
# 0     43615
# 1     27523
# 2  28684704
# 3  18693910
# 4  22551730

# %%
test['id_1']=map_1['book_id']

# %%
test.head()
# Out:
#    Unnamed: 0   id                                           features  \
# 0           0   43  [0.05561315268278122, -1.3075635433197021, -0....
# 1           1   63  [0.9563032984733582, 0.07040280103683472, -1.7...
# 2           2  103  [0.6581641435623169, 0.8863093852996826, -0.29...
# 3           3  143  [-0.500838577747345, 1.2483102083206177, -0.21...
# 4           4  183  [0.48275044560432434, 0.09569288045167923, 0.5...
#
#        id_1
# 0     43615
# 1     27523
# 2  28684704
# 3  18693910
# 4  22551730

# %%
index_id=list(map_1['book_id'])

# %%
test['features'].to_csv("features_book_final.csv",sep="\t",index=None)
# Out:
# C:\Users\Hitesh Arsenal Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
features=pd.read_csv("features_book_final.csv",sep=",",header=None)

# %%
features.ix[:,0] = features.ix[:,0].str.strip().str.replace('[',"")
features.ix[:,99] =features.ix[:,99] .str.strip().str.replace(']',"")
# Out:
# C:\Users\Hitesh Arsenal Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\Hitesh Arsenal Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
features=features.astype(float)

# %%
df.index=df.book_id

# %%
df.head()
# Out:
#          children  comics, graphic  fantasy, paranormal  fiction  \
# book_id
# 5333265       NaN              NaN                  NaN      NaN
# 1333909       NaN              NaN                  NaN    219.0
# 7327624       NaN              NaN                 31.0      8.0
# 6066819       NaN              NaN                  NaN    555.0
# 287140        NaN              NaN                  NaN      NaN
#
#          history, historical fiction, biography  mystery, thriller, crime  \
# book_id
# 5333265                                     1.0                       NaN
# 1333909                                     5.0                       NaN
# 7327624                                     NaN                       1.0
# 6066819                                     NaN                      10.0
# 287140                                      NaN                       NaN
#
#          non-fiction  poetry  romance  young-adult  book_id
# book_id
# ...

# %%
type(index_id)
# Out:
# list

# %%
df_new=df.ix[index_id,:]
# Out:
# C:\Users\Hitesh Arsenal Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df_new.head()
# Out:
#           children  comics, graphic  fantasy, paranormal  fiction  \
# book_id
# 43615          NaN              NaN              10730.0   4317.0
# 27523          NaN              NaN                269.0   1270.0
# 28684704       NaN              NaN                634.0   3969.0
# 18693910       NaN              NaN                  NaN      7.0
# 22551730       NaN              NaN                  NaN    103.0
#
#           history, historical fiction, biography  mystery, thriller, crime  \
# book_id
# 43615                                        NaN                     385.0
# 27523                                        NaN                     150.0
# 28684704                                     NaN                    2071.0
# 18693910                                   192.0                       NaN
# 22551730                                  1076.0                       NaN
#
#           non-fiction  poetry  romance  young-adult   book_id
# book_id
# ...

# %%
df_new.drop(['book_id'],axis=1,inplace=True)

# %%
features.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.055613 -1.307564 -0.938409  2.681387 -0.028332  0.434310 -0.759581
# 1  0.956303  0.070403 -1.740556  0.150269 -0.173502  0.196401  0.672676
# 2  0.658164  0.886309 -0.292798  0.877812  0.364470  0.344237 -0.062275
# 3 -0.500839  1.248310 -0.217342 -0.028320  0.271278  0.037977 -0.200087
# 4  0.482750  0.095693  0.529231  0.214702  0.889620 -0.190329 -0.440311
#
#          7         8         9   ...        90        91        92        93  \
# 0 -2.589776 -2.178298 -0.328223  ...  1.130805 -0.743120  0.661973 -2.846066
# 1 -0.421331 -0.234456  1.258662  ... -0.003298 -0.758793 -0.820045  1.193710
# 2 -0.146851  0.130402  0.155895  ...  0.343821  0.167370 -0.095957 -0.162771
# 3  0.052727  0.385433  0.472707  ...  0.610173 -0.191432  0.172378 -0.174339
# 4  0.488739  0.851246 -0.252487  ... -0.872647 -0.026482  0.448258  0.693774
#
#          94        95        96        97        98        99
# ...

# %%
genre=list(df_new.eq(df_new.max(1), axis=0).dot(df_new.columns))

# %%
features.to_csv("features_final_tsne.csv",index=None)

# %%
df_new['book_id']=df_new.index

# %%
df_new['book_id']
# Out:
# book_id
# 43615          43615
# 27523          27523
# 28684704    28684704
# 18693910    18693910
# 22551730    22551730
# 17855756    17855756
# 12961964    12961964
# 10281556    10281556
# 809849        809849
# 944102        944102
# 7315573      7315573
# 12727969    12727969
# 1852            1852
# 175675        175675
# 157993        157993
# 9938498      9938498
# 6719017      6719017
# 7905092      7905092
# 1111            1111
# 24280          24280
# 3760            3760
# 84699          84699
# 136251        136251
# 514313        514313
# 555313        555313
# 10883          10883
# 18122          18122
# 125404        125404
# 7679            7679
# 97782          97782
#               ...
# 2896085      2896085
# 16445406    16445406
# 8464407      8464407
# 6787340      6787340
# 6105517      6105517
# 15861433    15861433
# 3412087      3412087
# 28019303    28019303
# 13172107    13172107
# 35207152    35207152
# 9833642      9833642
# 1726982      1726982
# ...

# %%
df_new['genre']=genre

df_final=pd.DataFrame(df_new['genre'])

# %%
df_final.to_csv("genre_tsne.csv",index=None)

# %%
pd.read_csv("features_final_tsne.csv")
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.055613 -1.307564 -0.938409  2.681387 -0.028332  0.434310 -0.759581
# 1      0.956303  0.070403 -1.740556  0.150269 -0.173502  0.196401  0.672676
# 2      0.658164  0.886309 -0.292798  0.877812  0.364470  0.344237 -0.062275
# 3     -0.500839  1.248310 -0.217342 -0.028320  0.271278  0.037977 -0.200087
# 4      0.482750  0.095693  0.529231  0.214702  0.889620 -0.190329 -0.440311
# 5      0.404817 -0.259524  0.326662 -0.524998 -0.041327 -0.049367  0.092096
# 6      0.275400  0.800016 -0.174447 -0.148405  0.964846 -0.225742 -0.130172
# 7     -1.970055 -0.110670 -0.312471  0.203522  0.467579  0.161074 -0.304797
# 8      0.060929 -0.396446  0.657943 -0.545475 -0.429373 -0.435862  0.273455
# 9      0.250702 -0.555262  0.158784  0.050374 -0.384739 -0.726122  0.185896
# 10     0.996479  1.791765  0.016074  0.365068  0.080646  0.634163 -0.729393
# ...
